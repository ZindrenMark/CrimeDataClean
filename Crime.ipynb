# %%
import pandas as pd

# %%
filename = 'C:/Users/mzindren/Documents/MontCountCrime.csv'

# %%
df = pd.read_csv(filename)

# %%
## Check that data was loaded correctly
df.head()
# Out:
#    Incident ID Offence Code  CR Number Dispatch Date/Time NIBRS Code  Victims  \
# 0    201090098         2203   16036935    7/21/2016 13:23        220        1
# 1    201090098         2901   16036935    7/21/2016 13:23        290        1
# 2    201089849         3522   16036571    7/19/2016 16:35        35A        1
# 3    201089849         3550   16036571    7/19/2016 16:35        35B        1
# 4    201090376         2203   16037277     7/23/2016 9:25        220        1
#
#               Crime Name1                               Crime Name2  \
# 0  Crime Against Property            Burglary/Breaking and Entering
# 1  Crime Against Property  Destruction/Damage/Vandalism of Property
# 2   Crime Against Society                  Drug/Narcotic Violations
# 3   Crime Against Society                 Drug Equipment Violations
# 4  Crime Against Property            Burglary/Breaking and Entering
#
#                               Crime Name3 Police District Name  ... Sector  \
# ...

# %%
df.dtypes
# Out:
# Incident ID                 int64
# Offence Code               object
# CR Number                   int64
# Dispatch Date/Time         object
# NIBRS Code                 object
# Victims                     int64
# Crime Name1                object
# Crime Name2                object
# Crime Name3                object
# Police District Name       object
# Block_Address              object
# City                       object
# State                      object
# Zip Code                  float64
# Agency                     object
# Place                      object
# Sector                     object
# Beat                       object
# PRA                        object
# Address Number            float64
# Start Date/Time            object
# End Date/Time              object
# Latitude                  float64
# Longitude                 float64
# Police District Number     object
# Location                   object
# dtype: object

# %%
dfdt = df[["End Date/Time", "Start Date/Time"]]

dfdt.head()
# Out:
#      End Date/Time  Start Date/Time
# 0   7/21/2016 9:00  7/20/2016 19:00
# 1   7/21/2016 9:00  7/20/2016 19:00
# 2              NaN  7/19/2016 16:35
# 3              NaN  7/19/2016 16:35
# 4  7/12/2016 11:00  7/11/2016 14:00

# %%
dfdt.dtypes
# Out:
# End Date/Time      object
# Start Date/Time    object
# dtype: object

# %%
dfdt.dropna()

#dfdt2 = pd.to_datetime(dfdt.stack()).unstack()

df['Start Date/Time'] = pd.to_datetime(df['Start Date/Time'])
df['End Date/Time'] = pd.to_datetime(df['End Date/Time'])

df.dtypes
# Out:
# Incident ID                        int64
# Offence Code                      object
# CR Number                          int64
# Dispatch Date/Time                object
# NIBRS Code                        object
# Victims                            int64
# Crime Name1                       object
# Crime Name2                       object
# Crime Name3                       object
# Police District Name              object
# Block_Address                     object
# City                              object
# State                             object
# Zip Code                         float64
# Agency                            object
# Place                             object
# Sector                            object
# Beat                              object
# PRA                               object
# Address Number                   float64
# Start Date/Time           datetime64[ns]
# End Date/Time             datetime64[ns]
# Latitude                         float64
# ...

# %%
df['Start Date'] = df['Start Date/Time'].dt.date
df['Start Time'] = df['Start Date/Time'].dt.time

df['End Date'] = df['End Date/Time'].dt.date
df['End Time'] = df['End Date/Time'].dt.time

df.head()
# Out:
#    Incident ID Offence Code  CR Number Dispatch Date/Time NIBRS Code  Victims  \
# 0    201090098         2203   16036935    7/21/2016 13:23        220        1
# 1    201090098         2901   16036935    7/21/2016 13:23        290        1
# 2    201089849         3522   16036571    7/19/2016 16:35        35A        1
# 3    201089849         3550   16036571    7/19/2016 16:35        35B        1
# 4    201090376         2203   16037277     7/23/2016 9:25        220        1
#
#               Crime Name1                               Crime Name2  \
# 0  Crime Against Property            Burglary/Breaking and Entering
# 1  Crime Against Property  Destruction/Damage/Vandalism of Property
# 2   Crime Against Society                  Drug/Narcotic Violations
# 3   Crime Against Society                 Drug Equipment Violations
# 4  Crime Against Property            Burglary/Breaking and Entering
#
#                               Crime Name3 Police District Name  ...  \
# ...

# %%
dfdt2['New Date'] = dfdt2['Start Date/Time'].dt.date

dfdt2.head()
# Out:
#         End Date/Time     Start Date/Time    New Date
# 0 2016-07-21 09:00:00 2016-07-20 19:00:00  2016-07-20
# 1 2016-07-21 09:00:00 2016-07-20 19:00:00  2016-07-20
# 2                 NaT 2016-07-19 16:35:00  2016-07-19
# 3                 NaT 2016-07-19 16:35:00  2016-07-19
# 4 2016-07-12 11:00:00 2016-07-11 14:00:00  2016-07-11
